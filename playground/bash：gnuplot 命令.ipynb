# %%
cat > /tmp/gnuplot_data.txt <<EOF
1     1   2.1
2     4   4.5
3     900   6
4    16   8
5    25   10
6    36   11
7    49   12
8    64   13
9    81   14
10  100   15
EOF

gnuplot -e "
set terminal png;
plot '/tmp/gnuplot_data.txt' using 1:2 with linespoints linecolor 3 linewidth 1 pointtype 5 pointsize 1, '' using 1:2:2 with labels title 'a','/tmp/gnuplot_data.txt' using 1:3 with linespoints linecolor 3 linewidth 1 pointtype 5 pointsize 1, '' using 1:3:3 with labels title 'b'" | display
