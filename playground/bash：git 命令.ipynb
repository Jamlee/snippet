# %% [markdown]
# ![image.png](attachment:44c17a9c-7c3e-4b57-9f1f-5ed672c47d11.png)

# %%
git clone --recursive 仓库地址
git submodule update --recursive --init
git submodule update --recursive --remote
git pull --recurse-submodules
